# %% [markdown]
# # Run and process benchmarks
# This notebook demonstrates how to run (a set of) benchmarks, validate the results, and add the results to the website.

# %%
import sys

import pandas as pd

sys.path.insert(0, "..")
from runner.utils import (
    allocate_benchmarks,
    check_uptimes,
    create_benchmark_campaign,
    fetch_all_partial_results,
    load_benchmark_metadata,
    load_results,
    plot_runtime_slowdowns,
)

# %%
# If a util function was modified, use this cell to reload it without having to restart the kernel
# %run ../runner/utils.py

# %% [markdown]
# ## Create benchmark campaign(s)
# First, ensure that the desired benchmarks have been processed and categorized (following our PR template) and their metadata is present and up-to-date in `results/metadata.yaml`. Then, adapt the following cells to run the benchmarks of your choosing. This example runs benchmarks from [PR #314](https://github.com/open-energy-transition/solver-benchmark/pull/314).

# %% [markdown]
# ### 20260225 Run IESA-Opt-NL benchmarks

# %%
to_run = {"IESA-Opt-NL": ["1-3h", "1-1h", "10-3h"]}

bench_sizes_to_run = set()
for b, sizes in to_run.items():
    for s in sizes:
        bench_sizes_to_run.add(b + "-" + s)

benchmarks_df = load_benchmark_metadata()
benchs_to_run = benchmarks_df[benchmarks_df.index.isin(bench_sizes_to_run)].copy()
benchs_to_run
# Out:
#                      Benchmark Instance Modelling framework   Model name  \
# IESA-Opt-NL-1-3h   IESA-Opt-NL     1-3h            IESA-Opt  IESA-Opt-NL
# IESA-Opt-NL-1-1h   IESA-Opt-NL     1-1h            IESA-Opt  IESA-Opt-NL
# IESA-Opt-NL-10-3h  IESA-Opt-NL    10-3h            IESA-Opt  IESA-Opt-NL
#
#                     Version    Contributor(s)/Source    License Problem class  \
# IESA-Opt-NL-1-3h   20251218  TNO, Utrecht University  CC BY 4.0            LP
# IESA-Opt-NL-1-1h   20251218  TNO, Utrecht University  CC BY 4.0            LP
# IESA-Opt-NL-10-3h  20251218  TNO, Utrecht University  CC BY 4.0            LP
#
#                                            Application  Sectoral focus  ...  \
# IESA-Opt-NL-1-3h   Infrastructure & Capacity Expansion  Sector-coupled  ...
# IESA-Opt-NL-1-1h   Infrastructure & Capacity Expansion  Sector-coupled  ...
# IESA-Opt-NL-10-3h  Infrastructure & Capacity Expansion  Sector-coupled  ...
#
#                   Temporal resolution Spatial resolution Realistic  \
# IESA-Opt-NL-1-3h     2920 time slices             1 node      True
# IESA-Opt-NL-1-1h     8760 time slices             1 node      True
# IESA-Opt-NL-10-3h    2920 time slices           10 nodes      True
#
#                   Num. constraints Num. variables Skip because Num. nonzeros  \
# IESA-Opt-NL-1-3h            793714         493813          NaN           NaN
# IESA-Opt-NL-1-1h           1967554        1107013          NaN           NaN
# IESA-Opt-NL-10-3h          7603326        5672804          NaN           NaN
#
#                    Num. continuous variables  Num. integer variables  Notes
# IESA-Opt-NL-1-3h                         NaN                     NaN    NaN
# IESA-Opt-NL-1-1h                         NaN                     NaN    NaN
# IESA-Opt-NL-10-3h                        NaN                     NaN    NaN
#
# [3 rows x 25 columns]

# %%
# Create campaign:

# Allocate the Ls
l_to_run = benchs_to_run.query('Size == "L"')
vm_yamls = allocate_benchmarks(
    l_to_run,
    "Num. variables",
    len(l_to_run),  # 1 instance per VM since we're running only 3 benchmarks
    machine_type="c4-highmem-16",
    timeout_seconds=24 * 60 * 60,
    years=[2024, 2025],  # latest solvers only, so skip creating older conda envs
    # NOTE: this function also lets you choose the zone and solvers to run. For the website, we use the defaults
)
# Allocate the Ss and Ms
vm_yamls += allocate_benchmarks(
    benchs_to_run.query('Size != "L"'),
    "Num. variables",
    len(benchs_to_run) - len(l_to_run),
)

campaign_name = "iesa-opt-nl"
create_benchmark_campaign(
    f"20260225-{campaign_name}",
    campaign_name,
    vm_yamls,
)
# Out:
# Allocated. Estimated runtime: 1575.8h
#   VM 00: 1 instances, 1575.8h
#   VM 01: 1 instances, 307.5h
# Allocated. Estimated runtime: 137.2h
#   VM 00: 1 instances, 137.2h
# Created directory and files in ../infrastructure/benchmarks/20260225-iesa-opt-nl
# Run this campaign from the infrastructure/ directory using the command:
# tofu apply -var-file benchmarks/20260225-iesa-opt-nl/run.tfvars -state=states/20260225-iesa-opt-nl.tfstate

# %% [markdown]
# **Before launching** the run using the `tofu apply` command above, take a second to:
# 1. Estimate cost before launching a run, it's easy to launch something costing $1000s!
# 1. Estimate runtime and make sure we're running as much as possible in parallel!
# 1. Also check if anyone else is already running benchmarks, and if we have enough gurobi licenses for the number of VMs you want to launch (our current limit is 40).
# 1. Finally, inspect the yaml files in the `infrastructure/<run-id>/` directory to check that you're launching the benchmarks that you expect.

# %% [markdown]
# ## Monitor runs
#
# I recommend:
# 1. 10 minutes after launching the run with the `tofu apply` command above, run the following command to view running VMs and ensure that the VMs started successfully:
#     ```
#     gcloud compute instances list | sort | tee /dev/tty | grep benchmark-instance | grep -i running | wc -l
#     ```
# 1. A few hours after launching the run, use the `check_uptimes()` command in the cell below to check that the VMs have load average >= 1, which means they haven't hung and are crunching away happily.
# 1. If running large instances with a 24h timeout, use the `fetch_all_partial_results()` command in the cell below to fetch partial results after a day and check that it looks as you expect. E.g., if all solvers are timing out or erroring, perhaps it might be worth killing the run to save costs.
#
# In case of errors, use these commands to SSH into a running VM and see what's happening:
# ```
# gcloud compute ssh projects/compute-app-427709/zones/us-central1-a/instances/benchmark-instance-more-pypsa-de-sizes-04
# tail -f /var/log/startup-script.log
# cat /solver-benchmark/results/benchmark_results.csv
# ```

# %%
check_uptimes()
# Out:
# There are 1 running instances
# benchmark-instance-00-campaign: 06:30:23 up 2 days, 15:32,  1 user,  load average: 1.09, 1.04, 1.08
#
# 0 potentially hung instances:

# %%
fetch_all_partial_results()
# Out:
# Cleared ../results/partial-results
# There are 1 running VMs. Fetching results from: benchmark-instance-00-campaign	us-central1-a Done.

# %% [markdown]
# ## Validate results
#
# To download results:
# ```
# gsutil -m rsync -r gs://solver-benchmarks/results ./results/gcp-results/
# ```

# %%
results, variability = load_results(
    ["../results/gcp-results/20260225-iesa-opt-nl/"]
)  # Multiple folders can be specified here if multiple campaigns were run
benchmarks_df = load_benchmark_metadata()
# Out:
# Found 29 records, 3 benchmark instances

# %% [markdown]
# ### Drop results superceeded by newer runs

# %%
# Find the Run IDs and Hostnames for each bench-size instance and drop all but the latest
# NOTE: assumes all Run IDs begin with YYYYMMDD-
runs_grouped = results.groupby("bench-size")[["Run ID", "Hostname"]]
to_drop = set()
for bench_size, group in runs_grouped:
    unique_runs = group[["Run ID", "Hostname"]].drop_duplicates()
    if len(unique_runs) > 1:
        sorted_runs = sorted(unique_runs.itertuples(index=False))
        to_drop.update([(*run, bench_size) for run in sorted_runs[:-1]])

print("Dropping results from these runs:", sorted(to_drop))
keys = pd.MultiIndex.from_frame(results[["Run ID", "Hostname", "bench-size"]])
results = results.loc[~keys.isin(to_drop)].copy()
print(
    f"After dropping: {len(results)} records, {len(results['bench-size'].unique())} benchmark instances"
)
# Out:
# Dropping results from these runs: []
# After dropping: 29 records, 3 benchmark instances

# %% [markdown]
# ### Validate runtime variability

# %%
# Calculate the runtime variability for each benchmark instance

runtimes = results.query('Status == "ok"')
runtimes = runtimes.groupby(["bench-size"])["Runtime (s)"].agg(list)

runtime_stats = pd.DataFrame(
    {
        "runtimes": runtimes,
        "mean_runtime": runtimes.apply(lambda x: sum(x) / len(x)),
    }
)
runtime_stats["VM"] = runtime_stats.index.map(
    lambda bs: (
        results[results["bench-size"] == bs]["Hostname"].iloc[0],
        results[results["bench-size"] == bs]["Run ID"].iloc[0],
        results[results["bench-size"] == bs]["VM Zone"].iloc[0],
    )
    if any(results["bench-size"] == bs)
    else None
)
runtime_stats["observed_var"] = runtime_stats.apply(
    lambda r: variability.loc[r["VM"], ("std %", "")], axis=1
)
high_var_benchs = runtime_stats.query("observed_var > 6").sort_values(
    "observed_var", ascending=False
)
high_var_benchs if len(
    high_var_benchs
) > 0 else "No benchmark instance had observed runtime variability > 6%"
# Out:
# 'No benchmark instance had observed runtime variability > 6%'

# %% [markdown]
# ### Check results are complete

# %%
from collections import Counter

seen_solvers = Counter()
for bench_size, group in results.groupby("bench-size"):
    solvers_present = sorted(group["solver-version"])
    seen_solvers[str(solvers_present)] += 1
    if len(solvers_present) not in {4, 6, 15, 17}:
        print("Odd combination of solvers run on", bench_size, solvers_present)

seen_solvers
# Out:
# Counter({"['cbc-2.10.12', 'gurobi-13.0.0', 'highs-1.12.0', 'highs-hipo-1.12.0-hipo', 'highs-ipm-1.12.0-hipo', 'scip-10.0.0']": 2,
#          "['cbc-2.10.11', 'cbc-2.10.12', 'glpk-5.0', 'gurobi-10.0.0', 'gurobi-11.0.0', 'gurobi-12.0.0', 'gurobi-13.0.0', 'highs-1.12.0', 'highs-1.5.0.dev0', 'highs-1.6.0.dev0', 'highs-1.9.0', 'highs-hipo-1.12.0-hipo', 'highs-ipm-1.12.0-hipo', 'scip-10.0.0', 'scip-8.0.3', 'scip-8.1.0', 'scip-9.2.0']": 1})

# %%
# Check that there are no benchmarks in results/metadata.yaml that don't have results yet
benchs_available = benchmarks_df[benchmarks_df["Skip because"].isna()].index
benchs_run_so_far = set(results["bench-size"].unique())
print("Benchmarks without results:", sorted(set(benchs_available) - benchs_run_so_far))
# Out:
# Benchmarks without results: ['DCOPF-Carolinas_2M-997-1h', 'DCOPF-Carolinas_6M-997-1h', 'DCOPF-Carolinas_uc_2M-997-1h', 'DCOPF-Carolinas_uc_6M-997-1h', 'FINE-1-node-energy-system-workflow-1-8760ts', 'FINE-2-node-electricity-supply-system-2-8760ts', 'FINE-district-optimization-14-8760ts', 'FINE-energyland-1-8760ts', 'FINE-hydrogen-partload-1-168ts', 'FINE-multi-regional-energy-system-workflow-8-8760ts', 'FINE-perfect-foresight-1-8760ts', 'FINE-spatial-aggregation-of-energy-system-model-8-8760ts', 'FINE-water-supply-system-12-8760ts', 'IESA-Opt-NL-10-1h', 'IESA-Opt-NL-20-3h', 'IESA-Opt-NL-25-3h', 'IESA-Opt-NL-5-3h', 'OEMOF-diesel-genset-nonconvex-investment-1-240ts', 'OEMOF-economic-results-1-8760ts', 'OEMOF-house-with-nonconvex-investment-1-365ts', 'OEMOF-house-without-nonconvex-investment-1-365ts', 'OEMOF-invest-optimize-all-technologies-using-mp-and-tsam-1-1920ts', 'OEMOF-offset-diesel-genset-nonconvex-investment-1-8760ts', 'OEMOF-result-object-1-8760ts', 'OEMOF-simple-dispatch-1-8760ts', 'OEMOF-tuple-as-label-1-8760ts', 'OEMOF-v1-invest-optimize-all-technologies-1-8760ts', 'OEMOF-v2-invest-optimize-only-gas-and-storage-1-8760ts', 'OEMOF-v3-invest-optimize-only-storage-with-fossil-share-1-8760ts', 'OEMOF-v4-invest-optimize-all-technologies-with-fossil-share-1-8760ts', 'SWITCH-3-zone-tiny-3-6ts', 'SWITCH-3-zone-toy-3-6ts', 'SWITCH-3zone-toy-stochastic-PySP-3-6ts', 'SWITCH-China-open-model-32-433ts', 'SWITCH-USA-PG-26-168h', 'SWITCH-carbon-cap-3-6ts', 'SWITCH-hydrogen-3-6ts', 'SWITCH-planning-reserves-3-6ts', 'SWITCH-retrofits-3-6ts', 'SWITCH-rps-simple-3-6ts', 'Sienna_modified_RTS_GMLC_DA_sys_NetCopperPlate_Horizon12_Day29-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetCopperPlate_Horizon12_Day314-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetCopperPlate_Horizon12_Day332-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetCopperPlate_Horizon24_Day29-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetCopperPlate_Horizon24_Day314-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetCopperPlate_Horizon24_Day332-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetCopperPlate_Horizon48_Day29-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetCopperPlate_Horizon48_Day314-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetCopperPlate_Horizon48_Day332-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetDC_Horizon12_Day29-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetDC_Horizon12_Day314-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetDC_Horizon12_Day332-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetDC_Horizon24_Day29-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetDC_Horizon24_Day314-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetDC_Horizon24_Day332-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetDC_Horizon48_Day29-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetDC_Horizon48_Day314-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetDC_Horizon48_Day332-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetPTDF_Horizon12_Day29-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetPTDF_Horizon12_Day314-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetPTDF_Horizon12_Day332-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetPTDF_Horizon24_Day29-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetPTDF_Horizon24_Day314-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetPTDF_Horizon24_Day332-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetPTDF_Horizon48_Day29-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetPTDF_Horizon48_Day314-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetPTDF_Horizon48_Day332-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetTransport_Horizon12_Day29-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetTransport_Horizon12_Day314-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetTransport_Horizon12_Day332-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetTransport_Horizon24_Day29-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetTransport_Horizon24_Day314-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetTransport_Horizon24_Day332-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetTransport_Horizon48_Day29-73-1h', 'Sienna_modified_RTS_GMLC_DA_sys_NetTransport_Horizon48_Day314-73-1h', 'Sienna_modified_RTS_GMLC_DA_sy ...

# %%
# Check that each instance only has results from 1 VM
found_error = False
for bench_size, group in results.groupby("bench-size")[["Run ID", "Hostname"]]:
    unique_hosts = group[["Run ID", "Hostname"]].drop_duplicates()
    if len(unique_hosts) > 1:
        print(f"ERROR: {bench_size} has results from > 1 VM: {unique_hosts}")
        found_error = True
if not found_error:
    print("All benchmarks have results from only one VM.")
# Out:
# All benchmarks have results from only one VM.

# %% [markdown]
# ### Check for solver errors and warnings

# %%
# Print any potential errors in latest solvers:
latest_solvers = {
    "cbc-2.10.12",
    "gurobi-13.0.0",
    "highs-hipo-1.12.0-hipo",
    "highs-ipm-1.12.0-hipo",
    "highs-1.12.0",
    "scip-10.0.0",
}
latest_results = results[results["solver-version"].isin(latest_solvers)]
latest_results.query('Status != "ok" and Status != "TO" and Status != "OOM"')[
    ["bench-size", "solver-version", "Status", "Timestamp", "Run ID", "Hostname"]
]
# Out:
# Empty DataFrame
# Columns: [bench-size, solver-version, Status, Timestamp, Run ID, Hostname]
# Index: []

# %%
# Check if anything has ok status without optimal solution
results.query(
    'Status == "ok" and `Termination Condition` != "optimal" and `Termination Condition` != "Optimal"'
)
# Out:
# Empty DataFrame
# Columns: [Benchmark, Size, Solver, Solver Version, Solver Release Year, Status, Termination Condition, Runtime (s), Memory Usage (MB), Objective Value, Max Integrality Violation, Duality Gap, Reported Runtime (s), Timeout, Hostname, Run ID, Timestamp, VM Instance Type, VM Zone, Solver benchmark version, bench-size, solver-version]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ### Validate objective values, MIP metrics

# %%
# Check that all solvers report similar objective values

# TODO only do this for ok/optimal results?
obj_dev = (
    results[(~results["Objective Value"].isna()) & (results["Solver"] != "glpk")]
    .groupby(["Benchmark", "Size"])
    .agg({"Objective Value": ["min", "max", "std"]})
)

obj_dev["std_ratio"] = (
    obj_dev[("Objective Value", "std")] / obj_dev[("Objective Value", "min")]
)
obj_dev[obj_dev["std_ratio"] > 1e-4].sort_values(by="std_ratio", ascending=False)
# Out:
# Empty DataFrame
# Columns: [(Objective Value, min), (Objective Value, max), (Objective Value, std), (std_ratio, )]
# Index: []

# %%
# Check if any results have high duality gap (above 1e-4)
results[results["Duality Gap"] > 1e-4].sort_values(by="Duality Gap", ascending=False)
# Out:
# Empty DataFrame
# Columns: [Benchmark, Size, Solver, Solver Version, Solver Release Year, Status, Termination Condition, Runtime (s), Memory Usage (MB), Objective Value, Max Integrality Violation, Duality Gap, Reported Runtime (s), Timeout, Hostname, Run ID, Timestamp, VM Instance Type, VM Zone, Solver benchmark version, bench-size, solver-version]
# Index: []
#
# [0 rows x 22 columns]

# %%
# Check if any results have high maximum integrality violation
results[results["Max Integrality Violation"] > 1e-5].sort_values(
    by="Max Integrality Violation", ascending=False
)
# Out:
# Empty DataFrame
# Columns: [Benchmark, Size, Solver, Solver Version, Solver Release Year, Status, Termination Condition, Runtime (s), Memory Usage (MB), Objective Value, Max Integrality Violation, Duality Gap, Reported Runtime (s), Timeout, Hostname, Run ID, Timestamp, VM Instance Type, VM Zone, Solver benchmark version, bench-size, solver-version]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ### Visualize results

# %%
# Keep only latest solver versions for plotting
max_years = results.groupby("Solver")["Solver Release Year"].max()
print("Before dropping:", results.shape)
results_latest = results[
    results["Solver Release Year"] == results["Solver"].map(max_years)
].copy()
print("After dropping:", results_latest.shape)
# Out:
# Before dropping: (29, 22)
# After dropping: (19, 22)

# %%
# TODO this is overwriting the results passed in!
plot_runtime_slowdowns(results_latest, figsize=(20, 6), max_num_solvers=7)

# %% [markdown]
# ## Write results to website

# %%
# Rename highs-ipm to highs-ipx
results_web = results.copy()
results_web["Solver"] = results_web["Solver"].map(
    lambda x: "highs-ipx" if x == "highs-ipm" else x
)
results_web["solver-version"] = results_web["solver-version"].map(
    lambda x: "highs-ipx-1.12.0-hipo" if x == "highs-ipm-1.12.0-hipo" else x
)

# %%
# Read results already on website to check columns match
results_old = pd.read_csv("../results/benchmark_results.csv")

# Unfortunately results CSV currently has a dummy Benchmark1 column at the end, so add it to these too
results_web["Benchmark1"] = None

assert str(results_old.columns) == str(results_web.columns)

# %%
# Append these results to website results
with open("../results/benchmark_results.csv", "a") as f:
    results_web.to_csv(f, index=False, header=False)
